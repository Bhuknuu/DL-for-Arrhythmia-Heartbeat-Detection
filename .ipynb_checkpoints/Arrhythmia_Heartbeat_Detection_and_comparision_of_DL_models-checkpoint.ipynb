# %% [markdown]
# # Comparison of DL Models for **Arrhythmia Heartbeat Detection**
# ### _for MIT-BIH Arrhythmia Database_

# %% [markdown]
# ---
# ### Phase A - Setup and Prepreparation
# ---
# * Fixing random seeds
# * importing the libraries used throughout
# * printing a reproducibility record (library versions + hardware)

# %%
import os
import sys
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import sklearn as skl
import imblearn

import wfdb
import shap

SEED = 88

# Set global seeds
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

#if running on GPUs (not in google colab)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

try:
    torch.use_deterministic_algorithms(True)
except (AttributeError, RuntimeError):
    pass

print("\n--- REPRODUCIBILITY RECORD ---")
print(f"Python version:          {sys.version.split()[0]}")
print(f"NumPy version:           {np.__version__}")
print(f"Pandas version:          {pd.__version__}")
print(f"PyTorch version:         {torch.__version__}")
print(f"Scikit-Learn version:    {skl.__version__}")
print(f"Imblearn version:        {imblearn.__version__}")
print(f"WFDB version:            {wfdb.__version__}")
print(f"SHAP version:            {shap.__version__}")
print(f"CUDA Available:          {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device:          {torch.cuda.get_device_name(0)}")
print("------------------------------")
# Out:
# --- REPRODUCIBILITY RECORD ---
# Python version:          3.12.10
# NumPy version:           1.26.4
# Pandas version:          2.2.2
# PyTorch version:         2.3.0+cpu
# Scikit-Learn version:    1.4.2
# Imblearn version:        0.12.2
# WFDB version:            4.1.2
# SHAP version:            0.45.1
# CUDA Available:          False
# ------------------------------

# %% [markdown]
# ---
# ### Phase B - Data Loading and Exploratory Visualization
# ---
# Loads a single MIT-BIH record (**100**) directly from PhysioNet via `wfdb.rdrecord()` / `wfdb.rdann()`
#
# * Visualizations used here:
#     1. **Raw waveform**
#     2. **Annotated waveform**
#     3. **Dual-lead comparison**
#     4. **RR-interval scatter plot**
# * Importing dataset using rdrecord()

# %%
db_record = wfdb.rdrecord('100', pn_dir='mitdb')
annotation = wfdb.rdann("mitbih_database/100", 'atr', pn_dir='mitdb')

num_samples = 3600
fs = db_record.fs

time_axis = np.arange(num_samples) / fs
signal_ch0 = db_record.p_signal[:num_samples, 0]

plt.figure(figsize=(12, 4),facecolor='lightgrey')
plt.plot(time_axis, signal_ch0, color='crimson', linewidth=1, label=db_record.sig_name[0])
plt.title(f"ECG Signal - Record {db_record.record_name} (Lead {db_record.sig_name[0]})")
plt.xlabel("Time (seconds)")
plt.ylabel("Voltage (mV)")
plt.grid(linestyle='--', alpha=0.6)
plt.legend(loc='upper right')
plt.show()


# # Get annotations within the first 10 seconds (sample < 3600)
# mask = annotation.sample < num_samples
# peak_samples = annotation.sample[mask]
# peak_symbols = np.array(annotation.symbol)[mask]

# # Convert peak sample indices to time & voltage values
# peak_times = peak_samples / fs
# peak_voltages = db_record.p_signal[peak_samples, 0]

# # Plot continuous signal
# plt.figure(figsize=(12, 4))
# plt.plot(time_axis, signal_ch0, color='navy', label='ECG Signal', alpha=0.8)

# # Overlay Scatter Plot for Annotations
# plt.scatter(peak_times, peak_voltages, color='red', s=50, zorder=5, label='R-Peak Marks')

# # Annotate each scatter point with its Cardiologist Symbol ('N', etc.)
# for t, v, symbol in zip(peak_times, peak_voltages, peak_symbols):
#     plt.text(t, v + 0.1, symbol, fontsize=10, fontweight='bold', ha='center')

# plt.title(f"Annotated ECG Signal - Record {db_record.record_name}")
# plt.xlabel("Time (seconds)")
# plt.ylabel("Voltage (mV)")
# plt.grid(True, linestyle='--', alpha=0.5)
# plt.legend()
# plt.show()

# fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

# # Channel 0 (MLII)
# axes[0].plot(time_axis, db_record.p_signal[:num_samples, 0], color='blue')
# axes[0].set_ylabel(f"{db_record.sig_name[0]} (mV)")
# axes[0].grid(True, linestyle='--')

# # Channel 1 (V1)
# axes[1].plot(time_axis, db_record.p_signal[:num_samples, 1], color='green')
# axes[1].set_ylabel(f"{db_record.sig_name[1]} (mV)")
# axes[1].set_xlabel("Time (seconds)")
# axes[1].grid(True, linestyle='--')

# plt.suptitle(f"Dual-Lead ECG Comparison - Record {db_record.record_name}")
# plt.show()

# # Compute RR-intervals (differences between consecutive peak samples in milliseconds)
# rr_intervals = np.diff(annotation.sample) / fs * 1000  # in ms

# rr_n = rr_intervals[:-1]    # RR_n
# rr_n_plus_1 = rr_intervals[1:] # RR_{n+1}

# plt.figure(figsize=(6, 6))
# plt.scatter(rr_n, rr_n_plus_1, color='purple', alpha=0.5, s=15)
# plt.plot([200, 1200], [200, 1200], color='gray', linestyle='--')  # Identity line x=y
# plt.title(f"Poincaré Scatter Plot (RR_n vs RR_n+1) - Record {db_record.record_name}")
# plt.xlabel("RR_n (ms)")
# plt.ylabel("RR_n+1 (ms)")
# plt.grid(True)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 18
#      14 # plt.grid(linestyle='--', alpha=0.6)
#      15 # plt.legend(loc='upper right')
#      16 # plt.show()
#      17
# ---> 18 annotation = wfdb.rdann("mitbih_database/100", 'atr')
#      19
#      20 # # Get annotations within the first 10 seconds (sample < 3600)
#      21 # mask = annotation.sample < num_samples
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\wfdb\io\annotation.py:1950, in rdann(record_name, extension, sampfrom, sampto, shift_samps, pn_dir, return_label_elements, summarize_labels)
#    1945 return_label_elements = check_read_inputs(
#    1946     sampfrom, sampto, return_label_elements
#    1947 )
#    1949 # Read the file in byte pairs
# -> 1950 filebytes = load_byte_pairs(record_name, extension, pn_dir)
#    1952 # Get WFDB annotation fields from the file bytes
#    1953 (sample, label_store, subtype, chan, num, aux_note) = proc_ann_bytes(
#    1954     filebytes, sampto
#    1955 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\wfdb\io\annotation.py:2091, in load_byte_pairs(record_name, extension, pn_dir)
#    2089 # local file
#    2090 if pn_dir is None:
# -> 2091     with open(record_name + "." + extension, "rb") as f:
#    2092         filebytes = np.fromfile(f, "<u1").reshape([-1, 2])
#    2093 # PhysioNet file
#    2094 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mitbih_database/100.atr'

# %%
annotation = wfdb.rdann("100", 'atr', pn_dir="mitdb")
