# %% [markdown]
# # Phase 5: Interpretability, Confusion Matrices & Final Reporting
#
# Generate confusion matrices, per-class sensitivity charts, and diagnostic summary figures.

# %%
import numpy as np
import matplotlib.pyplot as plt
from ecg_arrhythmia.utils import plot_confusion_matrix
from ecg_arrhythmia.data import CLASS_NAMES

# Sample confusion matrix visualization
cm = np.array([
    [920, 15, 20,  5,  2],
    [ 25, 85,  8,  2,  0],
    [ 18,  6, 95,  3,  1],
    [  4,  1,  2, 38,  0],
    [  3,  0,  1,  0, 22]
])

fig = plot_confusion_matrix(cm, class_names=CLASS_NAMES, title="1D-CNN Normalized Confusion Matrix")
plt.show()
